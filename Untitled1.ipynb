# %% [markdown]
# <a href="https://colab.research.google.com/github/JuwelAakon247/Machine-learning/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Conversation opened. 1 read message.

Skip to content
Using Gmail with screen readers
2 of 1,434
(no subject)
Inbox

Mohosiul Haque Alvi <mohosiulhaquealvi@gmail.com>
Attachments
10:35 AM (22 minutes ago)
to me


 One attachment
  •  Scanned by Gmail
# -*- coding: utf-8 -*-
"""Untitled3.ipynb

Automatically generated by Colab.

Original file is located at
    https://colab.research.google.com/drive/1oSF-UYWkj_f3M5D9kkf2oPoql6pBGpTj
"""

#from ch:1 two pronlems
#problem 1 variable and literal

x = 30
y = 25.8

a="Dhaka"
print(a)
print(type((a)))


z = x+y

print( 'result', z)
print( 'data type ', type(z))
print('datatype', type(x))


#problem 2

a = int(input('enter the 1st number:' ))
b = int (input('enter the 2nd number:'))

print('sum', a+b)
print('sub', a-b)
print('mul',a*b)
print('div',a/b)





#from ch-2 two problems
#if else conditions

char = input("Enter a  letter: ")
char_lower = char.lower()

if char_lower == 'a':
    print(f"'{char}' is a vowel.")
elif char_lower == 'e':
    print(f"'{char}' is a vowel.")
elif char_lower == 'i':
    print(f"'{char}' is a vowel.")
elif char_lower == 'o':
    print(f"'{char}' is a vowel.")
elif char_lower == 'u':
    print(f"'{char}' is a vowel.")
else:
    print(f"'{char}' is a consonant.")

#prblm 2
number_str = input("Enter a  number: ")
number = int(number_str)

if number > 0:
    print("The number is positive.")
elif number < 0:
    print("The number is negative.")
else:
    print("The number is zero.")

#from ch-3 two problems

#prblm 1
secret_number = 7
guess = 0
print("Guess the secret number between 1 and 10")

while guess != secret_number:
    guess_str = input("Enter your guess: ")
    guess = int(guess_str)
    if guess != secret_number:
        print("Wrong guess, try again!")

print("Congratulations! You guessed the secret number!")

#prblm2
count = 5

print("Start countdown:")
while count > 0:
    print(count)
    count = count - 1
    if count == 0:
        print("Countdown complete")

#ch4 prblm no 1



fruits = ["apple", "banana","cherry","mango"]
print(f"fruits: {fruits}")


fruits.append("cherry")
print(f"Fruits after append: {fruits}")

fruits.remove("banana")
print(f"Fruits after remove: {fruits}")
fruits.insert(1, "orange")
print(f"Fruits after insert: {fruits}")

#prblm 2 in this different types of dt empty list are checked


ages = [22, 35, 18, 40]
print(f"Ages: {ages}")

mixed_list = ["text", 123, 3.14, True]
print(f"Mixed list: {mixed_list}")


empty_list = []
print(f"Empty list: {empty_list}")

# 2 problem from ch-5
# pblm 1 creating  dictionary
person = {
    "name": "Alice",
    "age": 30,
    "city": "New York"
}
print("about person")
print(f"Person: {person}")
print(f"Type of person: {type(person)}")

#problm 2
student = {
    "name": "Alvi",
    "grade": "A",
    "age": 23,
    "is_enrolled": True,
    "courses": ["Math", "Science", "History"]
}

print(f"Student: {student}")
print("\n")
untitled3.py
Displaying untitled3.py.
# Out:
#   File "<ipython-input-1-3330197375>", line 11
#     10:35 AM (22 minutes ago)
#          ^
# SyntaxError: invalid non-printable character U+202F
